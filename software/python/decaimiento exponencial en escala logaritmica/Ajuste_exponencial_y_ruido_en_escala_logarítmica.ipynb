# %% [markdown]
# * Está en Colab: [LINK](https://colab.research.google.com/drive/1S3c_EXja-x5oGgsD6rUGjKx0x-6YOdLS?usp=sharing)
# * También está en github: [LINK](https://github.com/diegoshalom/labosdf/blob/master/software/python/decaimiento%20exponencial%20en%20escala%20logaritmica/Ajuste_exponencial_y_ruido_en_escala_logar%C3%ADtmica.ipynb)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
random_state = 42
np.random.seed(random_state)
plt.figure(figsize=(10,5))

for offset in [20, 10,0,-10, -20]:
    A = 200
    tau = 10
    tamruido = 1.2
    x = np.arange(0,100,0.01)
    ruido = tamruido * np.random.randn(len(x))
    y = offset + A*np.exp(-x/tau) + ruido

    plt.subplot(1, 2, 1)
    plt.scatter(x, y, s=1, label=f'offset = {offset}')
    plt.grid(True)
    plt.legend()
    plt.xlabel('x')
    plt.ylabel('y')

    plt.subplot(1, 2, 2)
    plt.scatter(x, y, s=1)
    plt.yscale('log')
    plt.grid(True)
    plt.xlabel('x')
    plt.ylabel('y')

# %%
random_state = 42
np.random.seed(random_state)
plt.figure(figsize=(10,5))

for offset in [20, 10,0,-10, -20]:
    A = 200
    tau = 10
    tamruido = 1.2
    x = np.arange(0,100,0.01)
    ruido = tamruido * np.random.randn(len(x))
    y = offset + A*np.exp(-x/tau) + ruido

    plt.subplot(1, 2, 1)
    plt.scatter(x, y, s=1, label=f'offset = {offset}')
    plt.grid(True)
    plt.legend()
    plt.xlabel('x')
    plt.ylabel('y')

    plt.subplot(1, 2, 2)
    plt.scatter(x, y, s=1)
    x_fit = x[y>0]
    y_fit = y[y>0]
    p = np.polyfit(x_fit,np.log10(y_fit),1)
    plt.plot(x_fit,10**(np.polyval(p,x_fit)), 'k', linewidth=3)
    plt.plot(x_fit,10**(np.polyval(p,x_fit)))
    plt.yscale('log')
    plt.grid(True)
    plt.xlabel('x')
    plt.ylabel('y')

# %%
random_state = 42
np.random.seed(random_state)
plt.figure(figsize=(10,5))

for offset in [20, 10,0,-10, -20]:
    A = 200
    tau = 10
    tamruido = 1.2
    x = np.arange(0,60,0.01)
    ruido = tamruido * np.random.randn(len(x))
    y = offset + A*np.exp(-x/tau) + ruido

    plt.subplot(1, 2, 1)
    plt.scatter(x, y, s=1, label=f'offset = {offset}')
    plt.grid(True)
    plt.legend()
    plt.xlabel('x')
    plt.ylabel('y')
    plt.xlim([0, 100])

    plt.subplot(1, 2, 2)
    plt.scatter(x, y, s=1)
    x_fit = x[y>0]
    y_fit = y[y>0]
    p = np.polyfit(x_fit,np.log10(y_fit),1)
    plt.plot(x_fit,10**(np.polyval(p,x_fit)), 'k', linewidth=3)
    plt.plot(x_fit,10**(np.polyval(p,x_fit)))
    plt.yscale('log')
    plt.grid(True)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.xlim([0, 100])
